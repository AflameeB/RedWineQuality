# %% [markdown]
# ## Project - Applying Data Science Methodology on Red Wine Quality Dataset
#
# <img src="https://media.giphy.com/media/jRuv9xc10lVyE/giphy.gif">
#
# You can read more about the Data Science Methodology from this [IBM whitepaper](https://tdwi.org/~/media/64511A895D86457E964174EDC5C4C7B1.PDF) by John Rollins
#
# [Link](https://archive.ics.uci.edu/ml/datasets/wine+quality) for the dataset for context
#
# <img src="https://media-exp1.licdn.com/dms/image/C4D12AQGOPVf5iqhhwQ/article-inline_image-shrink_1000_1488/0/1597756152693?e=1652918400&v=beta&t=iKZ2jX3khsx11lD9JyZWDz-j-Gt2hZsKPXz5rZ0iE1M">

# %% [markdown]
# ### Business Understanding
#
# The red wine industry shows a recent exponential growth as social drinking is on the rise. Nowadays, industry players are using product quality certifications to promote their products. This is a time-consuming process and requires the assessment given by human experts, which makes this process very expensive. Also, the price of red wine depends on a rather abstract concept of wine appreciation by wine tasters, opinion among whom may have a high degree of variability. Another vital factor in red wine certification and quality assessment is physicochemical tests, which are laboratory-based and consider factors like acidity, pH level, sugar, and other chemical properties. The red wine market would be of interest if the human quality of tasting can be related to wine’s chemical properties so that certification and quality assessment and assurance processes are more controlled.
#
# The goal is to implement Regression Models and Classification Models on the Red Wine Quality Dataset to determine which features are the best quality red wine indicators and generate insights into each of these factors to our model’s red wine quality.

# %% [markdown]
# ### Analytic Approach
# Based on the above business understanding one should decide the analytical approach to follow. The approaches can be of 4 types: Descriptive approach (current status and information provided), Diagnostic approach(a.k.a statistical analysis, what is happening and why it is happening), Predictive approach(it forecasts on the trends or future events probability) and Prescriptive approach( how the problem should be solved actually).
#
# **Q1. What is the analytical approach that you would take for this project? Why do you think its the right approach?**
#
# *I would take Descriptive approach as we yet do not know what information is useful and has high impact on our wine quality.We are only given raw data, and using a descriptive technique can help us grasp the potential links between variables as well as present the data in a more comprehensible manner. After our analysis is finished, we would do the modellings.*

# %% [markdown]
# ### Data Requirements
#
# **Q2. What kind of data do we require for predicting the red wine quality and for determining the features that are the best quality red wine indicators?**
#
# *We need data with a lot of elements, such as physiochemical qualities (acidity, pH level, sugar, etc.) so that we may play around with them and figure out which ones are the best quality red wine indicators.*

# %% [markdown]
# ### Data Collection
#
# **Q3. From where do we get our data?**
#
# *We get our data from Wine Quality Dataset which is gathered by:*
# - *Paulo Cortez, University of Minho, Guimarães, Portugal, http://www3.dsi.uminho.pt/pcortez*
# - *A. Cerdeira, F. Almeida, T. Matos and J. Reis, Viticulture Commission of the Vinho Verde Region(CVRVV), Porto, Portugal
# @2009*
#
# *and is accessible on UCI ML repository via this link https://archive.ics.uci.edu/ml/datasets/wine+quality*
#
# The file winequality-red.csv contains records of wine attributes and their rankings. The data is mostly quantitative. The type of data we require is integer and ratio, also ordinal since we need the quality to know how much of an attribute will provide the best quality.

# %% [markdown]
# ### Data Understanding
#
# Link for the dataset https://archive.ics.uci.edu/ml/datasets/wine+quality for context
#
# **Q4. From where are red wine samples obtained?**
#
# The red wine samples are the variants of the Portuguese "Vinho Verde" wine, it is obtained from the north of Portugal.
#
# **Q5. How can knowing the impact of each variable on the red wine quality help businesses(producers, distributors, etc) ?**
#
# *Knowing the impact of each variable would help businesses(producers, distributors, etc) better assess their production, distribution, and pricing strategy.*

# %%
import matplotlib.pyplot as plt
import joblib
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
from sklearn.preprocessing import normalize, StandardScaler
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.model_selection import GridSearchCV

redwine = pd.read_csv('winequality-red.csv')
features = redwine.drop("quality", axis=1)
labels = redwine["quality"]
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# **_Shape of the Data_**

# %%
print('Number of samples: ', redwine.shape[0])
print('Number of features: ', redwine.shape[1])
# Out:
# Number of samples:  1599
# Number of features:  12

# %% [markdown]
# **_Datatypes of the features_**

# %%
redwine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# **_Understanding the Data_**

# %%
print(list(redwine.columns))
redwine['quality'].value_counts()
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# From the above table, we can see that the data in our dataset is not distributed well and we have a lot more medium quality wines than the very high or low quality wines.

# %%
for i, col in enumerate(list(redwine.drop('quality', axis=1).columns)):
    plt.figure(i)
    sns.catplot(x='quality', y=col, data=redwine, kind='point', aspect=2, )

# %% [markdown]
# #### Observations
# 1. when there is low volatile acidity, chlorides, density, and pH, the quality of the wine is higher
# 2. when there is increase in citric acid, sulphates, and alcohol the quality becomes higher.
# 3. The residual sugar does not have much of a impact, across different wine qualities, the residual sugar remains the same.
#
# The rest of the features have a mixture of behaviours regarding their impact on the quality.

# %% [markdown]
# ### Data Preparation
#
# #### Explore the dataset further
# <li>Check for missing values and handle if any</li>
# <li>Check for outliers if any and handle them</li>
# <li>Implement Correlation heatmap</li>
# <li>Check the distribution of data using histograms</li>
# <li>Prepare the data for modeling by carrying out any steps that you think are necessary</li>

# %% [markdown]
# ### Check for missing values and handle if any

# %%
redwine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **Here, we can see our data has no missing values.**

# %% [markdown]
#  ### Check for outliers if any and handle them

# %%
fig = plt.figure(figsize = (15,8))
redwine.drop(['quality'], axis=1).boxplot(grid=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are obviously some outliers in our dataset which need to be handled.
# Also, from this graph we can see that the features are not on the same scale so we have class imbalance which can be solved using feature scaling.

# %%
df = redwine.copy()

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# This part of the code is taken from StackOverflow
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Number of outliers detected %d" % (len(redwine) - len(df)))
print("Proportion of outliers to the whole dataset is %f" % ((len(redwine) - len(df))/len(redwine)))
# Out:
# Number of outliers detected 420
# Proportion of outliers to the whole dataset is 0.262664

# %% [markdown]
# As the number of outliers detected in total are more than 25% of our dataset, then not dropping them would be more reasonable. We will try to cap and floor the outliers by the 10th and 90th percentile.

# %%
df = redwine.copy()

tenth_percentile = df.quantile(0.1)
ninetieth_percentile = df.quantile(0.9)

df = df.drop(['quality'], axis=1).clip(tenth_percentile, ninetieth_percentile, axis = 1)

# savng the dataframe for future use
df = df.assign(quality = redwine['quality'])
redwineMod = df

redwineMod.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4             0.700        0.010             1.9      0.076
# 1            7.8             0.745        0.010             2.6      0.098
# 2            7.8             0.745        0.040             2.3      0.092
# 3           10.7             0.310        0.522             1.9      0.075
# 4            7.4             0.700        0.010             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Implement Correlation Heatmap

# %%
plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(redwine.corr(), dtype=np.bool))
heatmap = sns.heatmap(redwine.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(redwine.corr()[['pH']].sort_values(by='pH', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Sales Price', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# #### Observations
#
# No feature that is highly correlated (correlation > 0.5) with the `quality` of the wines.

# %% [markdown]
# ### Check the distribution of data using histograms

# %%
for i in ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']:
    xmin = min(features[i])
    xmax = max(features[i] + 1)
    width = (xmax-xmin)/40
    sns.displot(data=redwine, x=features[i], hue="quality", multiple="stack")
    plt.title('Overlaid histogram for {}'.format(i))
    plt.show()

# %% [markdown]
# #### Observations
# This distribution in histograms will help us have a basic understanding of effects of different features on the quality of the wine.

# %% [markdown]
# As we have mentioned earlier, the features are not on the same scale and we have class imbalance in our dataset. To fix this issue, we implement feature scaling by standard scalar.

# %%
# Prepare the data for modeling by carrying out any steps that you think are necessary
features = redwineMod.drop('quality', axis=1)
labels = redwineMod['quality']

# Creating Test and Train data
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# implementing feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Modeling
#
# <li>Implement Multivariable Linear Regression using any 2 Regression algorithms of your choice</li>
# <li>Implement a Neural Network using Tensorflow and Keras to classify wine quality</li>

# %% [markdown]
# *_Implement Multivariable Linear Regression using any 2 Regression algorithms of your choice_*

# %%
# First Multivariable Linear Regression (Random Forest)
from sklearn.ensemble import RandomForestRegressor
rfModel = RandomForestRegressor(n_estimators=500)
rfModel.fit(X_train,y_train)
rfPreds = rfModel.predict(X_test)

# Second Multivariable Linear Regression Model (Gradient Boosting)
# We used GridSearchCV to find the best hyperparameters but as the output was large, we just used the hyperparameters we got from our GridSearch
from sklearn.ensemble import GradientBoostingRegressor
gbModel = GradientBoostingRegressor(learning_rate=0.1, max_depth=3, n_estimators=250)
gbModel.fit(X_train,y_train)
gbPreds = gbModel.predict(X_test)

# %% [markdown]
# *_Implement a Neural Network using Tensorflow and Keras to classify wine quality_*

# %%
import tensorflow as tf
tf.version.VERSION
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD

n_classes = 10
y_train_nn = to_categorical(y_train, n_classes)
y_test_nn = to_categorical(y_test, n_classes)

nnModel = Sequential()
nnModel.add(Dense(5, activation='relu', input_shape=(11,)))
nnModel.add(Dense(10, activation='softmax'))

# %%
nnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 60
#
#  dense_1 (Dense)             (None, 10)                60
#
# =================================================================
# Total params: 120
# Trainable params: 120
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Neural Network Model Configuration
nnModel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Neural Network Model Training
history = nnModel.fit(X_train, y_train_nn, batch_size=128, epochs=200, verbose=1, validation_data=(X_test, y_test_nn))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 30ms/step - loss: 2.4728 - accuracy: 0.1634 - val_loss: 2.4017 - val_accuracy: 0.2031
# Epoch 2/200
# 10/10 [==============================] - 0s 8ms/step - loss: 2.4204 - accuracy: 0.1861 - val_loss: 2.3545 - val_accuracy: 0.2438
# Epoch 3/200
# 10/10 [==============================] - 0s 7ms/step - loss: 2.3707 - accuracy: 0.2072 - val_loss: 2.3102 - val_accuracy: 0.2656
# Epoch 4/200
# 10/10 [==============================] - 0s 8ms/step - loss: 2.3246 - accuracy: 0.2228 - val_loss: 2.2677 - val_accuracy: 0.2781
# Epoch 5/200
# 10/10 [==============================] - 0s 6ms/step - loss: 2.2803 - accuracy: 0.2377 - val_loss: 2.2275 - val_accuracy: 0.2875
# Epoch 6/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.2389 - accuracy: 0.2541 - val_loss: 2.1893 - val_accuracy: 0.3031
# Epoch 7/200
# 10/10 [==============================] - 0s 6ms/step - loss: 2.1993 - accuracy: 0.2721 - val_loss: 2.1527 - val_accuracy: 0.3219
# Epoch 8/200
# 10/10 [==============================] - 0s 6ms/step - loss: 2.1611 - accuracy: 0.2877 - val_loss: 2.1174 - val_accuracy: 0.3469
# Epoch 9/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1240 - accuracy: 0.3065 - val_loss: 2.0831 - val_accuracy: 0.3594
# Epoch 10/200
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0885 - accuracy: 0.3206 - val_loss: 2.0490 - val_accuracy: 0.3719
# Epoch 11/200
# 10/10 [==============================] - 0s 7ms/step - loss: 2.0532 - accuracy: 0.3440 - val_loss: 2.0155 - val_accuracy: 0.3750
# Epoch 12/200
# 10/10 [==============================] - 0s 7ms/step - loss: 2.0184 - accuracy: 0.3581 - val_loss: 1.9823 - val_accuracy: 0.3750
# Epoch 13/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.9841 - accuracy: 0.3675 - val_loss: 1.9495 - val_accuracy: 0.3938
# Epoch 14/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.9503 - accuracy: 0.3792 - val_loss: 1.9171 - val_accuracy: 0.4000
# Epoch 15/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.9170 - accuracy: 0.3808 - val_loss: 1.8852 - val_accuracy: 0.4125
# Epoch 16/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8843 - accuracy: 0.3886 - val_loss: 1.8529 - val_accuracy: 0.4219
# Epoch 17/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8505 - accuracy: 0.4019 - val_loss: 1.8211 - val_accuracy: 0.4250
# Epoch 18/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8178 - accuracy: 0.4120 - val_loss: 1.7888 - val_accuracy: 0.4344
# Epoch 19/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.7842 - accuracy: 0.4246 - val_loss: 1.7563 - val_accuracy: 0.4406
# Epoch 20/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.7509 - accuracy: 0.4355 - val_loss: 1.7240 - val_accuracy: 0.4531
# Epoch 21/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.7175 - accuracy: 0.4511 - val_loss: 1.6919 - val_accuracy: 0.4656
# Epoch 22/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.6845 - accuracy: 0.4652 - val_loss: 1.6603 - val_accuracy: 0.4875
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.6516 - accuracy: 0.4808 - val_loss: 1.6287 - val_accuracy: 0.4938
# Epoch 24/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.6188 - accuracy: 0.5004 - val_loss: 1.5977 - val_accuracy: 0.5063
# Epoch 25/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5875 - accuracy: 0.5035 - val_loss: 1.5667 - val_accuracy: 0.5156
# Epoch 26/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.5565 - accuracy: 0.5176 - val_loss: 1.5368 - val_accuracy: 0.5156
# Epoch 27/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5260 - accuracy: 0.5246 - val_loss: 1.5081 - val_accuracy: 0.5094
# Epoch 28/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4973 - accuracy: 0.5317 - val_loss: 1.4806 - val_accuracy: 0.5063
# Epoch 29/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4700 - accuracy: 0.5418 - val_loss: 1.4539 - val_accuracy: 0.5188
# Epoch 30/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4436 - accuracy: 0.5473 - val_loss: 1.4294 - val_accuracy: 0.5188
# Epoch 31/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4196 - accuracy: 0.5551 - val_loss: 1.4056 - val_accuracy: 0.5281
# Epoch 32/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3965 - accuracy: 0.5590 - val_loss: 1.3835 - val_accuracy: 0.5281
# Epoch 33/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3749 - accuracy: 0.5622 - val_loss: 1.3628 - val_accuracy: 0.5312
# Epoch 34/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3552 - accuracy: 0.5614 - val_loss: 1.3432 - val_accuracy: 0.5375
# Epoch 35/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3363 - accuracy: 0.5606 - val_loss: 1.3247 - val_accuracy: 0.5406
# Epoch 36/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3185 - accuracy: 0.5614 - val_loss: 1.3076 - val_accuracy: 0.5344
# Epoch 37/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3023 - accuracy: 0.5668 - val_loss: 1.2916 - val_accuracy: 0.5437
# Epoch 38/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2867 - accuracy: 0.5692 - val_loss: 1.2769 - val_accuracy: 0.5469
# Epoch 39/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2727 - accuracy: 0.5692 - val_loss: 1.2631 - val_accuracy: 0.5531
# Epoch 40/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2595 - accuracy: 0.5731 - val_loss: 1.2499 - val_accuracy: 0.5594
# Epoch 41/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2469 - accuracy: 0.5747 - val_loss: 1.2375 - val_accuracy: 0.5594
# Epoch 42/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2346 - accuracy: 0.5754 - val_loss: 1.2263 - val_accuracy: 0.5594
# Epoch 43/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2237 - accuracy: 0.5786 - val_loss: 1.2156 - val_accuracy: 0.5562
# Epoch 44/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2131 - accuracy: 0.5833 - val_loss: 1.2053 - val_accuracy: 0.5562
# Epoch 45/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2032 - accuracy: 0.5856 - val_loss: 1.1957 - val_accuracy: 0.5562
# Epoch 46/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1936 - accuracy: 0.5880 - val_loss: 1.1867 - val_accuracy: 0.5562
# Epoch 47/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1848 - accuracy: 0.5880 - val_loss: 1.1783 - val_accuracy: 0.5531
# Epoch 48/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1764 - accuracy: 0.5856 - val_loss: 1.1702 - val_accuracy: 0.5531
# Epoch 49/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1684 - accuracy: 0.5833 - val_loss: 1.1628 - val_accuracy: 0.5562
# Epoch 50/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1608 - accuracy: 0.5856 - val_loss: 1.1557 - val_accuracy: 0.5562
# Epoch 51/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1536 - accuracy: 0.5856 - val_loss: 1.1488 - val_accuracy: 0.5562
# Epoch 52/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1466 - accuracy: 0.5856 - val_loss: 1.1425 - val_accuracy: 0.5594
# Epoch 53/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1402 - accuracy: 0.5841 - val_loss: 1.1362 - val_accuracy: 0.5625
# Epoch 54/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1338 - accuracy: 0.5856 - val_loss: 1.1305 - val_accuracy: 0.5656
# Epoch 55/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1280 - accuracy: 0.5864 - val_loss: 1.1248 - val_accuracy: 0.5656
# Epoch 56/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1222 - accuracy: 0.5872 - val_loss: 1.1196 - val_accuracy: 0.5688
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1167 - accuracy: 0.5887 - val_loss: 1.1146 - val_accuracy: 0.5656
# Epoch 58/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1115 - accuracy: 0.5880 - val_loss: 1.1097 - val_accuracy: 0.5656
# Epoch 59/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1064 - accuracy: 0.5880 - val_loss: 1.1052 - val_accuracy: 0.5656
# Epoch 60/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1015 - accuracy: 0.5887 - val_loss: 1.1008 - val_accuracy: 0.5719
# Epoch 61/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0967 - accuracy: 0.5895 - val_loss: 1.0967 - val_accuracy: 0.5719
# Epoch 62/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0923 - accuracy: 0.5903 - val_loss: 1.0926 - val_accuracy: 0.5719
# Epoch 63/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0880 - accuracy: 0.5911 - val_loss: 1.0888 - val_accuracy: 0.5688
# Epoch 64/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0837 - accuracy: 0.5903 - val_loss: 1.0850 - val_accuracy: 0.5656
# Epoch 65/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0796 - accuracy: 0.5895 - val_loss: 1.0814 - val_accuracy: 0.5656
# Epoch 66/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0757 - accuracy: 0.5903 - val_loss: 1.0780 - val_accuracy: 0.5656
# Epoch 67/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0722 - accuracy: 0.5911 - val_loss: 1.0744 - val_accuracy: 0.5656
# Epoch 68/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0684 - accuracy: 0.5887 - val_loss: 1.0710 - val_accuracy: 0.5656
# Epoch 69/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0649 - accuracy: 0.5880 - val_loss: 1.0678 - val_accuracy: 0.5656
# Epoch 70/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0615 - accuracy: 0.5895 - val_loss: 1.0647 - val_accuracy: 0.5656
# Epoch 71/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0584 - accuracy: 0.5895 - val_loss: 1.0617 - val_accuracy: 0.5656
# Epoch 72/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0553 - accuracy: 0.5895 - val_loss: 1.0590 - val_accuracy: 0.5656
# Epoch 73/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0524 - accuracy: 0.5880 - val_loss: 1.0561 - val_accuracy: 0.5656
# Epoch 74/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0495 - accuracy: 0.5934 - val_loss: 1.0533 - val_accuracy: 0.5781
# Epoch 75/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0468 - accuracy: 0.6028 - val_loss: 1.0508 - val_accuracy: 0.5656
# Epoch 76/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0441 - accuracy: 0.6044 - val_loss: 1.0483 - val_accuracy: 0.5656
# Epoch 77/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0416 - accuracy: 0.6044 - val_loss: 1.0459 - val_accuracy: 0.5656
# Epoch 78/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0391 - accuracy: 0.6059 - val_loss: 1.0435 - val_accuracy: 0.5594
# Epoch 79/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0367 - accuracy: 0.6036 - val_loss: 1.0415 - val_accuracy: 0.5562
# Epoch 80/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0345 - accuracy: 0.5997 - val_loss: 1.0392 - val_accuracy: 0.5531
# Epoch 81/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0323 - accuracy: 0.5981 - val_loss: 1.0370 - val_accuracy: 0.5469
# Epoch 82/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0300 - accuracy: 0.5997 - val_loss: 1.0351 - val_accuracy: 0.5469
# Epoch 83/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0280 - accuracy: 0.6005 - val_loss: 1.0331 - val_accuracy: 0.5469
# Epoch 84/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0259 - accuracy: 0.5989 - val_loss: 1.0313 - val_accuracy: 0.5469
# Epoch 85/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0238 - accuracy: 0.5958 - val_loss: 1.0293 - val_accuracy: 0.5469
# Epoch 86/200
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0220 - accuracy: 0.5942 - val_loss: 1.0277 - val_accuracy: 0.5469
# Epoch 87/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0200 - accuracy: 0.5942 - val_loss: 1.0260 - val_accuracy: 0.5562
# Epoch 88/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0182 - accuracy: 0.5927 - val_loss: 1.0241 - val_accuracy: 0.5469
# Epoch 89/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0164 - accuracy: 0.5942 - val_loss: 1.0225 - val_accuracy: 0.5562
# Epoch 90/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0147 - accuracy: 0.5942 - val_loss: 1.0209 - val_accuracy: 0.5562
# Epoch 91/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0130 - accuracy: 0.5958 - val_loss: 1.0194 - val_accuracy: 0.5531
# Epoch 92/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0114 - accuracy: 0.5958 - val_loss: 1.0180 - val_accuracy: 0.5531
# Epoch 93/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0099 - accuracy: 0.5958 - val_loss: 1.0166 - val_accuracy: 0.5562
# Epoch 94/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0084 - accuracy: 0.5973 - val_loss: 1.0152 - val_accuracy: 0.5562
# Epoch 95/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0071 - accuracy: 0.5950 - val_loss: 1.0139 - val_accuracy: 0.5562
# Epoch 96/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0053 - accuracy: 0.5966 - val_loss: 1.0125 - val_accuracy: 0.5562
# Epoch 97/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0040 - accuracy: 0.5989 - val_loss: 1.0110 - val_accuracy: 0.5562
# Epoch 98/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0026 - accuracy: 0.5989 - val_loss: 1.0100 - val_accuracy: 0.5562
# Epoch 99/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0013 - accuracy: 0.5973 - val_loss: 1.0088 - val_accuracy: 0.5594
# Epoch 100/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9998 - accuracy: 0.5997 - val_loss: 1.0076 - val_accuracy: 0.5594
# Epoch 101/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9986 - accuracy: 0.6005 - val_loss: 1.0064 - val_accuracy: 0.5594
# Epoch 102/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9974 - accuracy: 0.6013 - val_loss: 1.0054 - val_accuracy: 0.5562
# Epoch 103/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9961 - accuracy: 0.6020 - val_loss: 1.0041 - val_accuracy: 0.5594
# Epoch 104/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9949 - accuracy: 0.6028 - val_loss: 1.0030 - val_accuracy: 0.5594
# Epoch 105/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9936 - accuracy: 0.6052 - val_loss: 1.0019 - val_accuracy: 0.5594
# Epoch 106/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9925 - accuracy: 0.6075 - val_loss: 1.0010 - val_accuracy: 0.5594
# Epoch 107/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9914 - accuracy: 0.6052 - val_loss: 0.9999 - val_accuracy: 0.5562
# Epoch 108/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9902 - accuracy: 0.6044 - val_loss: 0.9990 - val_accuracy: 0.5562
# Epoch 109/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9892 - accuracy: 0.6020 - val_loss: 0.9982 - val_accuracy: 0.5688
# Epoch 110/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9881 - accuracy: 0.6013 - val_loss: 0.9973 - val_accuracy: 0.5719
# Epoch 111/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9871 - accuracy: 0.6036 - val_loss: 0.9965 - val_accuracy: 0.5688
# Epoch 112/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9861 - accuracy: 0.6036 - val_loss: 0.9956 - val_accuracy: 0.5594
# Epoch 113/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9852 - accuracy: 0.5997 - val_loss: 0.9948 - val_accuracy: 0.5656
# Epoch 114/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.9842 - accuracy: 0.5997 - val_loss: 0.9941 - val_accuracy: 0.5656
# Epoch 115/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.9832 - accuracy: 0.6052 - val_loss: 0.9935 - val_accuracy: 0.5594
# Epoch 116/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9824 - accuracy: 0.6036 - val_loss: 0.9926 - val_accuracy: 0.5625
# Epoch 117/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9815 - accuracy: 0.6059 - val_loss: 0.9919 - val_accuracy: 0.5656
# Epoch 118/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9806 - accuracy: 0.6044 - val_loss: 0.9912 - val_accuracy: 0.5688
# Epoch 119/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9796 - accuracy: 0.6044 - val_loss: 0.9906 - val_accuracy: 0.5688
# Epoch 120/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9788 - accuracy: 0.6028 - val_loss: 0.9899 - val_accuracy: 0.5656
# Epoch 121/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9779 - accuracy: 0.6044 - val_loss: 0.9891 - val_accuracy: 0.5656
# Epoch 122/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9771 - accuracy: 0.6059 - val_loss: 0.9883 - val_accuracy: 0.5688
# Epoch 123/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9763 - accuracy: 0.6083 - val_loss: 0.9878 - val_accuracy: 0.5688
# Epoch 124/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9754 - accuracy: 0.6099 - val_loss: 0.9868 - val_accuracy: 0.5688
# Epoch 125/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9747 - accuracy: 0.6091 - val_loss: 0.9861 - val_accuracy: 0.5688
# Epoch 126/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9739 - accuracy: 0.6091 - val_loss: 0.9854 - val_accuracy: 0.5688
# Epoch 127/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9731 - accuracy: 0.6091 - val_loss: 0.9847 - val_accuracy: 0.5656
# Epoch 128/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9723 - accuracy: 0.6099 - val_loss: 0.9841 - val_accuracy: 0.5688
# Epoch 129/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9715 - accuracy: 0.6106 - val_loss: 0.9833 - val_accuracy: 0.5688
# Epoch 130/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9709 - accuracy: 0.6091 - val_loss: 0.9825 - val_accuracy: 0.5688
# Epoch 131/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9702 - accuracy: 0.6075 - val_loss: 0.9817 - val_accuracy: 0.5688
# Epoch 132/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9694 - accuracy: 0.6091 - val_loss: 0.9811 - val_accuracy: 0.5688
# Epoch 133/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9687 - accuracy: 0.6083 - val_loss: 0.9807 - val_accuracy: 0.5688
# Epoch 134/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9680 - accuracy: 0.6083 - val_loss: 0.9801 - val_accuracy: 0.5594
# Epoch 135/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9672 - accuracy: 0.6083 - val_loss: 0.9794 - val_accuracy: 0.5656
# Epoch 136/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9665 - accuracy: 0.6083 - val_loss: 0.9788 - val_accuracy: 0.5625
# Epoch 137/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9658 - accuracy: 0.6091 - val_loss: 0.9783 - val_accuracy: 0.5625
# Epoch 138/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9651 - accuracy: 0.6091 - val_loss: 0.9777 - val_accuracy: 0.5594
# Epoch 139/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9645 - accuracy: 0.6075 - val_loss: 0.9770 - val_accuracy: 0.5625
# Epoch 140/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9638 - accuracy: 0.6091 - val_loss: 0.9764 - val_accuracy: 0.5594
# Epoch 141/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9632 - accuracy: 0.6091 - val_loss: 0.9759 - val_accuracy: 0.5594
# Epoch 142/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9626 - accuracy: 0.6059 - val_loss: 0.9755 - val_accuracy: 0.5594
# Epoch 143/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9619 - accuracy: 0.6083 - val_loss: 0.9750 - val_accuracy: 0.5625
# Epoch 144/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9613 - accuracy: 0.6075 - val_loss: 0.9743 - val_accuracy: 0.5625
# Epoch 145/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9608 - accuracy: 0.6067 - val_loss: 0.9740 - val_accuracy: 0.5656
# Epoch 146/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9601 - accuracy: 0.6099 - val_loss: 0.9734 - val_accuracy: 0.5656
# Epoch 147/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9596 - accuracy: 0.6106 - val_loss: 0.9726 - val_accuracy: 0.5656
# Epoch 148/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9590 - accuracy: 0.6075 - val_loss: 0.9725 - val_accuracy: 0.5656
# Epoch 149/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9584 - accuracy: 0.6075 - val_loss: 0.9718 - val_accuracy: 0.5656
# Epoch 150/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9580 - accuracy: 0.6083 - val_loss: 0.9713 - val_accuracy: 0.5688
# Epoch 151/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9573 - accuracy: 0.6091 - val_loss: 0.9708 - val_accuracy: 0.5656
# Epoch 152/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9570 - accuracy: 0.6083 - val_loss: 0.9701 - val_accuracy: 0.5688
# Epoch 153/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9565 - accuracy: 0.6091 - val_loss: 0.9698 - val_accuracy: 0.5625
# Epoch 154/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9560 - accuracy: 0.6075 - val_loss: 0.9692 - val_accuracy: 0.5656
# Epoch 155/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9555 - accuracy: 0.6083 - val_loss: 0.9687 - val_accuracy: 0.5656
# Epoch 156/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9551 - accuracy: 0.6106 - val_loss: 0.9683 - val_accuracy: 0.5656
# Epoch 157/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9548 - accuracy: 0.6106 - val_loss: 0.9679 - val_accuracy: 0.5656
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9542 - accuracy: 0.6106 - val_loss: 0.9676 - val_accuracy: 0.5656
# Epoch 159/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9538 - accuracy: 0.6114 - val_loss: 0.9670 - val_accuracy: 0.5625
# Epoch 160/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9534 - accuracy: 0.6106 - val_loss: 0.9668 - val_accuracy: 0.5656
# Epoch 161/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9531 - accuracy: 0.6114 - val_loss: 0.9662 - val_accuracy: 0.5656
# Epoch 162/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9526 - accuracy: 0.6114 - val_loss: 0.9660 - val_accuracy: 0.5625
# Epoch 163/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9522 - accuracy: 0.6122 - val_loss: 0.9656 - val_accuracy: 0.5656
# Epoch 164/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9518 - accuracy: 0.6122 - val_loss: 0.9654 - val_accuracy: 0.5656
# Epoch 165/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9515 - accuracy: 0.6122 - val_loss: 0.9649 - val_accuracy: 0.5656
# Epoch 166/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9511 - accuracy: 0.6130 - val_loss: 0.9644 - val_accuracy: 0.5656
# Epoch 167/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9507 - accuracy: 0.6130 - val_loss: 0.9641 - val_accuracy: 0.5656
# Epoch 168/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9503 - accuracy: 0.6138 - val_loss: 0.9639 - val_accuracy: 0.5656
# Epoch 169/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9499 - accuracy: 0.6153 - val_loss: 0.9636 - val_accuracy: 0.5688
# Epoch 170/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9495 - accuracy: 0.6145 - val_loss: 0.9631 - val_accuracy: 0.5656
# Epoch 171/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9491 - accuracy: 0.6138 - val_loss: 0.9629 - val_accuracy: 0.5688
# Epoch 172/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9488 - accuracy: 0.6138 - val_loss: 0.9624 - val_accuracy: 0.5688
# Epoch 173/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9484 - accuracy: 0.6161 - val_loss: 0.9622 - val_accuracy: 0.5688
# Epoch 174/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9480 - accuracy: 0.6169 - val_loss: 0.9618 - val_accuracy: 0.5688
# Epoch 175/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9476 - accuracy: 0.6177 - val_loss: 0.9615 - val_accuracy: 0.5688
# Epoch 176/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9472 - accuracy: 0.6192 - val_loss: 0.9613 - val_accuracy: 0.5688
# Epoch 177/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9469 - accuracy: 0.6177 - val_loss: 0.9611 - val_accuracy: 0.5688
# Epoch 178/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9464 - accuracy: 0.6169 - val_loss: 0.9607 - val_accuracy: 0.5688
# Epoch 179/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9460 - accuracy: 0.6169 - val_loss: 0.9605 - val_accuracy: 0.5688
# Epoch 180/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9457 - accuracy: 0.6200 - val_loss: 0.9602 - val_accuracy: 0.5688
# Epoch 181/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9452 - accuracy: 0.6208 - val_loss: 0.9599 - val_accuracy: 0.5688
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9450 - accuracy: 0.6200 - val_loss: 0.9597 - val_accuracy: 0.5688
# Epoch 183/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9446 - accuracy: 0.6200 - val_loss: 0.9596 - val_accuracy: 0.5688
# Epoch 184/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9443 - accuracy: 0.6192 - val_loss: 0.9590 - val_accuracy: 0.5688
# Epoch 185/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9439 - accuracy: 0.6185 - val_loss: 0.9588 - val_accuracy: 0.5719
# Epoch 186/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9435 - accuracy: 0.6192 - val_loss: 0.9586 - val_accuracy: 0.5719
# Epoch 187/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9431 - accuracy: 0.6177 - val_loss: 0.9581 - val_accuracy: 0.5719
# Epoch 188/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9428 - accuracy: 0.6192 - val_loss: 0.9581 - val_accuracy: 0.5719
# Epoch 189/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9425 - accuracy: 0.6185 - val_loss: 0.9577 - val_accuracy: 0.5750
# Epoch 190/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9421 - accuracy: 0.6192 - val_loss: 0.9574 - val_accuracy: 0.5750
# Epoch 191/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9418 - accuracy: 0.6185 - val_loss: 0.9570 - val_accuracy: 0.5750
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9414 - accuracy: 0.6185 - val_loss: 0.9568 - val_accuracy: 0.5750
# Epoch 193/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9412 - accuracy: 0.6192 - val_loss: 0.9565 - val_accuracy: 0.5781
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9408 - accuracy: 0.6185 - val_loss: 0.9563 - val_accuracy: 0.5781
# Epoch 195/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9405 - accuracy: 0.6185 - val_loss: 0.9560 - val_accuracy: 0.5781
# Epoch 196/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9402 - accuracy: 0.6185 - val_loss: 0.9557 - val_accuracy: 0.5781
# Epoch 197/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9399 - accuracy: 0.6177 - val_loss: 0.9556 - val_accuracy: 0.5781
# Epoch 198/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9396 - accuracy: 0.6161 - val_loss: 0.9553 - val_accuracy: 0.5781
# Epoch 199/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9394 - accuracy: 0.6161 - val_loss: 0.9549 - val_accuracy: 0.5813
# Epoch 200/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9391 - accuracy: 0.6161 - val_loss: 0.9546 - val_accuracy: 0.5781

# %% [markdown]
# ### Model Evaluation
#
# Evaluating the model accuracy is an essential part of the process in creating machine learning models to describe how well the model is performing in its predictions. Evaluation metrics change according to the problem type. Here, we'll briefly learn how to check the accuracy of the regression model.
#
# The linear model (regression) can be a typical example of this type of problem, and the main characteristic of the regression problem is that the targets of a dataset contain the real numbers only. The errors represent how much the model is making mistakes in its prediction. The basic concept of accuracy evaluation is to compare the original target with the predicted one according to certain metrics.
#
#
# **Regression model evaluation metrics**
#
# The MAE, RMSE, and R-Squared metrics are mainly used to evaluate the prediction error rates and model performance in regression analysis.
#
# **MAE (Mean absolute error)** represents the difference between the original and predicted values extracted by averaged the absolute difference over the data set.
#
# **RMSE (Root Mean Squared Error)** is the error rate by the square root of MSE.
#
# **R-squared (Coefficient of determination)** represents the coefficient of how well the values fit compared to the original values. The value from 0 to 1 interpreted as percentages. The higher the value is, the better the model is.
#
# The above metrics can be expressed as following:
# <img src = "https://4.bp.blogspot.com/-wG7IbjTfE6k/XGUvqm7TCVI/AAAAAAAAAZU/vpH1kuKTIooKTcVlnm1EVRCXLVZM9cPNgCLcBGAs/s1600/formula-MAE-MSE-RMSE-RSquared.JPG">
#
# Please find more information on how to implement them from this link: https://scikit-learn.org/stable/modules/classes.html#regression-metrics
#
# Find more about feature importances from here: https://machinelearningmastery.com/calculate-feature-importance-with-python/
#
# **Classification model evaluation metrics**
#
# <img src="https://www.researchgate.net/publication/336402347/figure/fig3/AS:812472659349505@1570719985505/Calculation-of-Precision-Recall-and-Accuracy-in-the-confusion-matrix.ppm">

# %% [markdown]
# **For Regression models**
# <li>Use three metrics: R-squared, RMSE, and MAE, to evaluate model prediction performance</li>
# <li>Compare these 3 metrics for the two models and analyze the performance</li>
# <li>Calculate the feature importance scores for the top features that help predicting wine quality and visualize them</li>
#
# **For Classification model**
# <li> Plot training loss and validation loss </li>
# <li> Plot training accuracy and validation accuracy </li>
# <li> Evaluate the classsification model using Precision, Recall and Accuracy metrics </li>

# %% [markdown]
# #### Regression Models

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from math import sqrt

def r2(y_, y):
    return r2_score(y_, y)
def rmse(y_, y):
    return sqrt(mean_squared_error(y_, y))
def mae(y_, y):
    return mean_absolute_error(y_, y)

print('Random Forest scores: R^2: {}, RMSE: {}, MAE: {}'.format(r2(y_test, rfPreds), rmse(y_test, rfPreds), mae(y_test, rfPreds)))
print('Gradient Boosting scores: R^2: {}, RMSE: {}, MAE: {}'.format(r2(y_test, gbPreds), rmse(y_test, gbPreds), mae(y_test, gbPreds)))
# Out:
# Random Forest scores: R^2: 0.518585552085357, RMSE: 0.5608985313762196, MAE: 0.42851874999999995
# Gradient Boosting scores: R^2: 0.48917187053888134, RMSE: 0.5777795217350751, MAE: 0.4523822849851932

# %% [markdown]
# As seen above, the Random Forest model outperforms the Gradient Boosting model in all of the R2, RMSE, and MAE metrics. The R2 of the Random Forest model is 0.52, whereas the R2 of the Gradient Boosting model is 0.49. (the higher, the better). The RMSE and MAE of the Random Forest model are 0.56 and 0.42, respectively, whereas the RMSE and MAE of the Gradient Boosting model are 0.58 and 0.45, respectively (the lower, the better).

# %%
# Calculating feature importance
from matplotlib import pyplot

rfImportance = rfModel.feature_importances_
gbImportance = gbModel.feature_importances_

featuresNames = list(redwineMod.columns)
# summarize feature importance
print("Random Forest Regression Feature Importance: ")
for i,v in enumerate(rfImportance):
    print('Feature: %20s, Score: %.5f' % (featuresNames[i],v))

print("\n\nGradient Boosting Regression Feature Importance: ")
for i,v in enumerate(gbImportance):
    print('Feature: %20s, Score: %.5f' % (featuresNames[i],v))
# Out:
# Random Forest Regression Feature Importance:
# Feature:        fixed acidity, Score: 0.05650
# Feature:     volatile acidity, Score: 0.09530
# Feature:          citric acid, Score: 0.05277
# Feature:       residual sugar, Score: 0.04793
# Feature:            chlorides, Score: 0.06856
# Feature:  free sulfur dioxide, Score: 0.05091
# Feature: total sulfur dioxide, Score: 0.08357
# Feature:              density, Score: 0.05623
# Feature:                   pH, Score: 0.05943
# Feature:            sulphates, Score: 0.15816
# Feature:              alcohol, Score: 0.27065
#
#
# Gradient Boosting Regression Feature Importance:
# Feature:        fixed acidity, Score: 0.06324
# Feature:     volatile acidity, Score: 0.10420
# Feature:          citric acid, Score: 0.04193
# Feature:       residual sugar, Score: 0.02628
# Feature:            chlorides, Score: 0.06052
# Feature:  free sulfur dioxide, Score: 0.03233
# Feature: total sulfur dioxide, Score: 0.08289
# Feature:              density, Score: 0.05641
# Feature:                   pH, Score: 0.05041
# Feature:            sulphates, Score: 0.17793
# Feature:              alcohol, Score: 0.30387

# %%
# plot feature importance
print("\n\nRandom Forest Regression Feature Importance Plot: ")
pyplot.figure(figsize=(20, 3))
pyplot.bar(featuresNames[:-1], list(rfImportance))
pyplot.show()

print("\n\nGradient Boosting Regression Feature Importance Plot: ")
pyplot.figure(figsize=(20, 3))
pyplot.bar(featuresNames[:-1], list(gbImportance))
pyplot.show()
# Out:
# Random Forest Regression Feature Importance Plot:
# Gradient Boosting Regression Feature Importance Plot:

# %% [markdown]
# As we can see from the graphs above, both of our regression models, had almost the same determination for features' importance. The highest feature importance is related to the `alcohol` feature which was predictable as the `alcohol` had the highest correlation with the wine's `quality`.

# %% [markdown]
# #### Classification Models

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training Accuracy Vs. Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training loss Vs. Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Our Neural Network operates as expected, as shown in the graphs above, which means that our model did not overfit or underfit the training data, and we have nearly identical accuracy ratings for both the train and test sets. The training and test losses are also the same, implying that the model's loss would be similar for unknown data.

# %%
y_predict = nnModel.predict(X_test)
y_predict_num = np.argmax(y_predict, axis=1)

# Got this code from https://machinelearningmastery.com/how-to-calculate-precision-recall-f1-and-more-for-deep-learning-models/
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_predict_num)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_predict_num, average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_predict_num, average='weighted')
print('Recall: %f' % recall)
# Out:
# Accuracy: 0.578125
# Precision: 0.541824
# Recall: 0.578125

# %% [markdown]
# The Neural Network model we have trained, has the scores of:
# - Accuracy: 0.58
# - Precision (weighted): 0.54
# - Recall (weighted): 0.58

# %% [markdown]
# The scores of our regression models:
# - Random Forest scores:
#   - R^2: 0.52
#   - RMSE: 0.56
#   - MAE: 0.42
# - Gradient Boosting scores:
#   - R^2: 0.49
#   - RMSE: 0.58
#   - MAE: 0.45
#
#
# The scores of our classification model (NN):
# - Accuracy: 0.58
# - Precision: 0.54
# - Recall: 0.58
#
#
# ### Conclusion
# We may deduce that the Neural Network model outperforms the other two regression models by comparing performance scores. The links between distinct aspects of the dataset are difficult to get since the 'wine quality' dataset comprises many features with moderate correlations between several of them, and regression methods are not good at finding complex associations. However, because Neural Network models are highly good at very difficult tasks, they can be quite beneficial in obtaining these correlations. However, Neural Network models require a big quantity of data, which we do not have, and as a result, the performance scores of our classification model were not as high as they could have been.
